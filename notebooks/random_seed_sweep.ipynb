# %%
import os, time, sys
import matplotlib.pyplot as plt
import ipywidgets as widgets
from IPython.display import display, display_html
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..')))

from src.utils.visualization import create_gif_dropdown, get_all_rewards, plot_all_losses
from src.utils.model_handling import load_checkpoint

# %% [markdown]
# ## Random seed sweep
#
# Half-decent models:
# - 532br / 1001
# - ux652 / 1004
# - 7z54i / 1000
#
# ## Architecture sweep
#
# Baseline 1:
# - h824i / 1000, 1004
# - a652d / 1002, 1003

# %%
create_gif_dropdown()
# Out:
# VBox(children=(Dropdown(description='Model:', layout=Layout(width='250px'), options=('Select a model...', '3s2…
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File c:\Work_Software\envs\lunar-transformer-il\Lib\site-packages\ipywidgets\widgets\widget.py:773, in Widget._handle_msg(self, msg)
#     771         if 'buffer_paths' in data:
#     772             _put_buffers(state, data['buffer_paths'], msg['buffers'])
# --> 773         self.set_state(state)
#     775 # Handle a state request.
#     776 elif method == 'request_state':
#
# File c:\Work_Software\envs\lunar-transformer-il\Lib\site-packages\ipywidgets\widgets\widget.py:650, in Widget.set_state(self, sync_data)
#     645         self._send(msg, buffers=echo_buffers)
#     647 # The order of these context managers is important. Properties must
#     648 # be locked when the hold_trait_notification context manager is
#     649 # released and notifications are fired.
# --> 650 with self._lock_property(**sync_data), self.hold_trait_notifications():
#     651     for name in sync_data:
#     652         if name in self.keys:
#
# File c:\Work_Software\envs\lunar-transformer-il\Lib\contextlib.py:144, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     142 if typ is None:
#     143     try:
# --> 144         next(self.gen)
#     145     except StopIteration:
#     146         return False
#
# File c:\Work_Software\envs\lunar-transformer-il\Lib\site-packages\traitlets\traitlets.py:1510, in HasTraits.hold_trait_notifications(self)
#    1508 for changes in cache.values():
#    1509     for change in changes:
# -> 1510         self.notify_change(change)
#
# File c:\Work_Software\envs\lunar-transformer-il\Lib\site-packages\ipywidgets\widgets\widget.py:701, in Widget.notify_change(self, change)
#     698     if name in self.keys and self._should_send_property(name, getattr(self, name)):
#     699         # Send new state to front-end
#     700         self.send_state(key=name)
# --> 701 super().notify_change(change)
#
# File c:\Work_Software\envs\lunar-transformer-il\Lib\site-packages\traitlets\traitlets.py:1525, in HasTraits.notify_change(self, change)
#    1523 def notify_change(self, change: Bunch) -> None:
#    1524     """Notify observers of a change event"""
# -> 1525     return self._notify_observers(change)
#
# File c:\Work_Software\envs\lunar-transformer-il\Lib\site-packages\traitlets\traitlets.py:1568, in HasTraits._notify_observers(self, event)
#    1565 elif isinstance(c, EventHandler) and c.name is not None:
#    1566     c = getattr(self, c.name)
# -> 1568 c(event)
#
# File c:\Work_Software\envs\lunar-transformer-il\Lib\site-packages\ipywidgets\widgets\widget_selection.py:236, in _Selection._propagate_index(self, change)
#     234     self.label = label
#     235 if self.value is not value:
# --> 236     self.value = value
#
# File c:\Work_Software\envs\lunar-transformer-il\Lib\site-packages\traitlets\traitlets.py:716, in TraitType.__set__(self, obj, value)
#     714 if self.read_only:
#     715     raise TraitError('The "%s" trait is read-only.' % self.name)
# --> 716 self.set(obj, value)
#
# File c:\Work_Software\envs\lunar-transformer-il\Lib\site-packages\traitlets\traitlets.py:706, in TraitType.set(self, obj, value)
#     702     silent = False
#     703 if silent is not True:
#     704     # we explicitly compare silent to True just in case the equality
#     705     # comparison above returns something other than True/False
# --> 706     obj._notify_trait(self.name, old_value, new_value)
#
# File c:\Work_Software\envs\lunar-transformer-il\Lib\site-packages\traitlets\traitlets.py:1513, in HasTraits._notify_trait(self, name, old_value, new_value)
#    1512 def _notify_trait(self, name: str, old_value: t.Any, new_value: t.Any) -> None:
# -> 1513     self.notify_change(
#    1514         Bunch(
#    1515             name=name,
#    1516             old=old_value,
#    1517             new=new_value,
#    1518             owner=self,
#    1519             type="change",
#    1520         )
#    1521     )
#
# File c:\Work_Software\envs\lunar-transformer-il\Lib\site-packages\ipywidgets\widgets\widget.py:701, in Widget.notify_change(self, change)
#     698     if name in self.keys and self._should_send_property(name, getattr(self, name)):
#     699         # Send new state to front-end
#     700         self.send_state(key=name)
# --> 701 super().notify_change(change)
#
# File c:\Work_Software\envs\lunar-transformer-il\Lib\site-packages\traitlets\traitlets.py:1525, in HasTraits.notify_change(self, change)
#    1523 def notify_change(self, change: Bunch) -> None:
#    1524     """Notify observers of a change event"""
# -> 1525     return self._notify_observers(change)
#
# File c:\Work_Software\envs\lunar-transformer-il\Lib\site-packages\traitlets\traitlets.py:1568, in HasTraits._notify_observers(self, event)
#    1565 elif isinstance(c, EventHandler) and c.name is not None:
#    1566     c = getattr(self, c.name)
# -> 1568 c(event)
#
# File c:\Github\lunar-transformer-il\src\utils\visualization.py:60, in create_gif_dropdown.<locals>.on_select(change)
#      58 if selected_name == "Select a model...":
#      59     return
# ---> 60 show_gifs_in_row(model_id=selected_name, output_widget=output)
#
# File c:\Github\lunar-transformer-il\src\utils\visualization.py:15, in show_gifs_in_row(model_id, width, output_widget)
#      12 results_root = os.path.join(project_root, 'results', 'models')
#      13 path = os.path.join(results_root, model_id, 'animations')
# ---> 15 gifs = [f for f in os.listdir(path) if f.lower().endswith('.gif')]
#      16 if not gifs:
#      17     print("No .gif files found in the provided path.")
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: 'c:\\Github\\lunar-transformer-il\\results\\models\\h824i\\animations'
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File c:\Work_Software\envs\lunar-transformer-il\Lib\site-packages\ipywidgets\widgets\widget.py:773, in Widget._handle_msg(self, msg)
#     771         if 'buffer_paths' in data:
#     772             _put_buffers(state, data['buffer_paths'], msg['buffers'])
# --> 773         self.set_state(state)
#     775 # Handle a state request.
#     776 elif method == 'request_state':
#
# File c:\Work_Software\envs\lunar-transformer-il\Lib\site-packages\ipywidgets\widgets\widget.py:650, in Widget.set_state(self, sync_data)
#     645         self._send(msg, buffers=echo_buffers)
#     647 # The order of these context managers is important. Properties must
#     648 # be locked when the hold_trait_notification context manager is
#     649 # released and notifications are fired.
# --> 650 with self._lock_property(**sync_data), self.hold_trait_notifications():
#     651     for name in sync_data:
#     652         if name in self.keys:
#
# File c:\Work_Software\envs\lunar-transformer-il\Lib\contextlib.py:144, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     142 if typ is None:
#     143     try:
# --> 144         next(self.gen)
#     145     except StopIteration:
#     146         return False
#
# File c:\Work_Software\envs\lunar-transformer-il\Lib\site-packages\traitlets\traitlets.py:1510, in HasTraits.hold_trait_notifications(self)
#    1508 for changes in cache.values():
#    1509     for change in changes:
# -> 1510         self.notify_change(change)
#
# File c:\Work_Software\envs\lunar-transformer-il\Lib\site-packages\ipywidgets\widgets\widget.py:701, in Widget.notify_change(self, change)
#     698     if name in self.keys and self._should_send_property(name, getattr(self, name)):
#     699         # Send new state to front-end
#     700         self.send_state(key=name)
# --> 701 super().notify_change(change)
#
# File c:\Work_Software\envs\lunar-transformer-il\Lib\site-packages\traitlets\traitlets.py:1525, in HasTraits.notify_change(self, change)
#    1523 def notify_change(self, change: Bunch) -> None:
#    1524     """Notify observers of a change event"""
# -> 1525     return self._notify_observers(change)
#
# File c:\Work_Software\envs\lunar-transformer-il\Lib\site-packages\traitlets\traitlets.py:1568, in HasTraits._notify_observers(self, event)
#    1565 elif isinstance(c, EventHandler) and c.name is not None:
#    1566     c = getattr(self, c.name)
# -> 1568 c(event)
#
# File c:\Work_Software\envs\lunar-transformer-il\Lib\site-packages\ipywidgets\widgets\widget_selection.py:236, in _Selection._propagate_index(self, change)
#     234     self.label = label
#     235 if self.value is not value:
# --> 236     self.value = value
#
# File c:\Work_Software\envs\lunar-transformer-il\Lib\site-packages\traitlets\traitlets.py:716, in TraitType.__set__(self, obj, value)
#     714 if self.read_only:
#     715     raise TraitError('The "%s" trait is read-only.' % self.name)
# --> 716 self.set(obj, value)
#
# File c:\Work_Software\envs\lunar-transformer-il\Lib\site-packages\traitlets\traitlets.py:706, in TraitType.set(self, obj, value)
#     702     silent = False
#     703 if silent is not True:
#     704     # we explicitly compare silent to True just in case the equality
#     705     # comparison above returns something other than True/False
# --> 706     obj._notify_trait(self.name, old_value, new_value)
#
# File c:\Work_Software\envs\lunar-transformer-il\Lib\site-packages\traitlets\traitlets.py:1513, in HasTraits._notify_trait(self, name, old_value, new_value)
#    1512 def _notify_trait(self, name: str, old_value: t.Any, new_value: t.Any) -> None:
# -> 1513     self.notify_change(
#    1514         Bunch(
#    1515             name=name,
#    1516             old=old_value,
#    1517             new=new_value,
#    1518             owner=self,
#    1519             type="change",
#    1520         )
#    1521     )
#
# File c:\Work_Software\envs\lunar-transformer-il\Lib\site-packages\ipywidgets\widgets\widget.py:701, in Widget.notify_change(self, change)
#     698     if name in self.keys and self._should_send_property(name, getattr(self, name)):
#     699         # Send new state to front-end
#     700         self.send_state(key=name)
# --> 701 super().notify_change(change)
#
# File c:\Work_Software\envs\lunar-transformer-il\Lib\site-packages\traitlets\traitlets.py:1525, in HasTraits.notify_change(self, change)
#    1523 def notify_change(self, change: Bunch) -> None:
#    1524     """Notify observers of a change event"""
# -> 1525     return self._notify_observers(change)
#
# File c:\Work_Software\envs\lunar-transformer-il\Lib\site-packages\traitlets\traitlets.py:1568, in HasTraits._notify_observers(self, event)
#    1565 elif isinstance(c, EventHandler) and c.name is not None:
#    1566     c = getattr(self, c.name)
# -> 1568 c(event)
#
# File c:\Github\lunar-transformer-il\src\utils\visualization.py:60, in create_gif_dropdown.<locals>.on_select(change)
#      58 if selected_name == "Select a model...":
#      59     return
# ---> 60 show_gifs_in_row(model_id=selected_name, output_widget=output)
#
# File c:\Github\lunar-transformer-il\src\utils\visualization.py:15, in show_gifs_in_row(model_id, width, output_widget)
#      12 results_root = os.path.join(project_root, 'results', 'models')
#      13 path = os.path.join(results_root, model_id, 'animations')
# ---> 15 gifs = [f for f in os.listdir(path) if f.lower().endswith('.gif')]
#      16 if not gifs:
#      17     print("No .gif files found in the provided path.")
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: 'c:\\Github\\lunar-transformer-il\\results\\models\\62xf8\\animations'

# %%
rewards, env_seeds = get_all_rewards()

plt.hist(rewards, bins=50)
plt.xlabel('accumulated reward')
plt.ylabel('count')
plt.show()

# %%
plot_all_losses(cap_epoch=5, tag=['532br', '7z54i'])
# Out:
# 3s28w
# 42l6y
# 4y1s0
# 62xf8
# 734gj
# 87w9v
# 89mq9
# 9k5g4
# a652d
# f68l2
# h0z29
# h824i
# n79a4
# w93s3
# z118s

# %%
chkpt = load_checkpoint(model_id='7z54i')
chkpt['seed']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 chkpt = load_checkpoint(model_id='7z54i')
#       2 chkpt['seed']
#
# File c:\Github\lunar-transformer-il\src\utils\model_handling.py:60, in load_checkpoint(model_id)
#      57 pth_files = sorted(list(Path(model_dir).rglob('*.pth')))
#      59 if not len(pth_files):
# ---> 60     raise ValueError(f'No .pth files in {model_dir}.')
#      62 if len(pth_files) > 1:
#      63     raise warnings.warn(f'{len(pth_files)} .pth files found in {os.path.join(project_root, model_id)}. The 1st element in the list will be used.')
#
# ValueError: No .pth files in c:\Github\lunar-transformer-il\results\models\7z54i.

# %%
chkpt = load_checkpoint(model_id='532br')
chkpt['seed']
# Out:
# 21

# %%
chkpt = load_checkpoint(model_id='ux652')
chkpt['seed']
# Out:
# 21
